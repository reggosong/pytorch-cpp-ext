# %%
import torch

def smooth_relu_ref(x, alpha=1.0):
    zero = torch.zeros_like(x)
    mid = x * x / (2.0*alpha)
    return torch.where(x<0, zero, torch.where(x>alpha, x, mid))

# %%
x = torch.tensor([-1., 0.2, 2.0], requires_grad=True)
y = smooth_relu_ref(x, 1.0).sum()
y.backward()
print(x.grad)
# Out:
# tensor([0.0000, 0.2000, 1.0000])

# %%
from torch.utils.cpp_extension import load_inline
import torch

src = r"""
#include <torch/extension.h>
torch::Tensor add_one(torch::Tensor x) { return x + 1; }
"""

ext = load_inline(
    name="demo_v1",
    cpp_sources=[src],      # just the function
    functions=["add_one"],  # let PyTorch autogenerate the pybind11 module
    verbose=True
)

print(ext.add_one(torch.tensor([1, 2, 3])))
# Out:
# tensor([2, 3, 4])

# %%
from torch.utils.cpp_extension import load_inline
import torch

src = r"""
#include <torch/extension.h>
torch::Tensor add_one(torch::Tensor x) { return x + 1; }

PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
  m.def("add_one", &add_one);
}
"""

ext = load_inline(
    name="demo_v2",
    cpp_sources=[src],      # only one source that defines the module
    functions=[],           # <- DO NOT pass functions here
    verbose=True
)

print(ext.add_one(torch.tensor([1, 2, 3])))
# Out:
# [1/2] c++ -MMD -MF main.o.d -DTORCH_EXTENSION_NAME=demo_v2 -DTORCH_API_INCLUDE_EXTENSION_H -isystem /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include -isystem /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -isystem /opt/homebrew/opt/python@3.12/Frameworks/Python.framework/Versions/3.12/include/python3.12 -fPIC -std=c++17 -c /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp -o main.o
# FAILED: [code=1] main.o
# c++ -MMD -MF main.o.d -DTORCH_EXTENSION_NAME=demo_v2 -DTORCH_API_INCLUDE_EXTENSION_H -isystem /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include -isystem /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -isystem /opt/homebrew/opt/python@3.12/Frameworks/Python.framework/Versions/3.12/include/python3.12 -fPIC -std=c++17 -c /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp -o main.o
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:10:1: error: redefinition of 'PyInit_demo_v2'
#    10 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:510:5: note: expanded from macro 'PYBIND11_MODULE'
#   510 |     PYBIND11_MODULE_PYINIT(                                                                       \
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:435:5: note: expanded from macro 'PYBIND11_MODULE_PYINIT'
#   435 |     PYBIND11_PLUGIN_IMPL(name) {                                                                  \
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:342:42: note: expanded from macro 'PYBIND11_PLUGIN_IMPL'
#   342 |     extern "C" PYBIND11_EXPORT PyObject *PyInit_##name()
#       |                                          ^
# <scratch space>:34:1: note: expanded from here
#    34 | PyInit_demo_v2
#       | ^
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:6:1: note: previous definition is here
#     6 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:510:5: note: expanded from macro 'PYBIND11_MODULE'
#   510 |     PYBIND11_MODULE_PYINIT(                                                                       \
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:435:5: note: expanded from macro 'PYBIND11_MODULE_PYINIT'
#   435 |     PYBIND11_PLUGIN_IMPL(name) {                                                                  \
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:342:42: note: expanded from macro 'PYBIND11_PLUGIN_IMPL'
#   342 |     extern "C" PYBIND11_EXPORT PyObject *PyInit_##name()
#       |                                          ^
# <scratch space>:23:1: note: expanded from here
#    23 | PyInit_demo_v2
#       | ^
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:10:1: error: redefinition of 'pybind11_exec_demo_v2'
#    10 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:512:5: note: expanded from macro 'PYBIND11_MODULE'
#   512 |     PYBIND11_MODULE_EXEC(name, variable)
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:455:9: note: expanded from macro 'PYBIND11_MODULE_EXEC'
#   455 |     int PYBIND11_CONCAT(pybind11_exec_, name)(PyObject * pm) {                                    \
#       |         ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:347:40: note: expanded from macro 'PYBIND11_CONCAT'
#   347 | #define PYBIND11_CONCAT(first, second) first##second
#       |                                        ^
# <scratch space>:40:1: note: expanded from here
#    40 | pybind11_exec_demo_v2
#       | ^
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:6:1: note: previous definition is here
#     6 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:512:5: note: expanded from macro 'PYBIND11_MODULE'
#   512 |     PYBIND11_MODULE_EXEC(name, variable)
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:455:9: note: expanded from macro 'PYBIND11_MODULE_EXEC'
#   455 |     int PYBIND11_CONCAT(pybind11_exec_, name)(PyObject * pm) {                                    \
#       |         ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:347:40: note: expanded from macro 'PYBIND11_CONCAT'
#   347 | #define PYBIND11_CONCAT(first, second) first##second
#       |                                        ^
# <scratch space>:29:1: note: expanded from here
#    29 | pybind11_exec_demo_v2
#       | ^
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:10:1: error: redefinition of 'pybind11_init_demo_v2'
#    10 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:512:5: note: expanded from macro 'PYBIND11_MODULE'
#   512 |     PYBIND11_MODULE_EXEC(name, variable)
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:467:10: note: expanded from macro 'PYBIND11_MODULE_EXEC'
#   467 |     void PYBIND11_CONCAT(pybind11_init_, name)(::pybind11::module_                                \
#       |          ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:347:40: note: expanded from macro 'PYBIND11_CONCAT'
#   347 | #define PYBIND11_CONCAT(first, second) first##second
#       |                                        ^
# <scratch space>:42:1: note: expanded from here
#    42 | pybind11_init_demo_v2
#       | ^
# /Users/regansong/Library/Caches/torch_extensions/py312_cpu/demo_v2/main.cpp:6:1: note: previous definition is here
#     6 | PYBIND11_MODULE(TORCH_EXTENSION_NAME, m) {
#       | ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:512:5: note: expanded from macro 'PYBIND11_MODULE'
#   512 |     PYBIND11_MODULE_EXEC(name, variable)
#       |     ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:467:10: note: expanded from macro 'PYBIND11_MODULE_EXEC'
#   467 |     void PYBIND11_CONCAT(pybind11_init_, name)(::pybind11::module_                                \
#       |          ^
# /Users/regansong/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/include/pybind11/detail/common.h:347:40: note: expanded from macro 'PYBIND11_CONCAT'
#   347 | #define PYBIND11_CONCAT(first, second) first##second
#       |                                        ^
# <scratch space>:31:1: note: expanded from here
#    31 | pybind11_init_demo_v2
#       | ^
# 3 errors generated.
# ninja: build stopped: subcommand failed.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2597, in _run_ninja_build(build_directory, verbose, error_prefix)
#    2596     stdout_fileno = 1
# -> 2597     subprocess.run(
#    2598         command,
#    2599         shell=IS_WINDOWS and IS_HIP_EXTENSION,
#    2600         stdout=stdout_fileno if verbose else subprocess.PIPE,
#    2601         stderr=subprocess.STDOUT,
#    2602         cwd=build_directory,
#    2603         check=True,
#    2604         env=env)
#    2605 except subprocess.CalledProcessError as e:
#    2606     # Python 2 and 3 compatible way of getting the error object.
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['ninja', '-v']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 13
#       2 import torch
#       4 src = r"""
#       5 #include <torch/extension.h>
#       6 torch::Tensor add_one(torch::Tensor x) { return x + 1; }
#    (...)     10 }
#      11 """
# ---> 13 ext = load_inline(
#      14     name="demo_v2",
#      15     cpp_sources=[src],      # only one source that defines the module
#      16     functions=[],           # <- DO NOT pass functions here
#      17     verbose=True
#      18 )
#      20 print(ext.add_one(torch.tensor([1, 2, 3])))
#
# File ~/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2051, in load_inline(name, cpp_sources, cuda_sources, sycl_sources, functions, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, with_pytorch_error_handling, keep_intermediates, use_pch, no_implicit_headers)
#    2047     _maybe_write(sycl_source_path, "\n".join(sycl_sources))
#    2049     sources.append(sycl_source_path)
# -> 2051 return _jit_compile(
#    2052     name,
#    2053     sources,
#    2054     extra_cflags,
#    2055     extra_cuda_cflags,
#    2056     extra_sycl_cflags,
#    2057     extra_ldflags,
#    2058     extra_include_paths,
#    2059     build_directory,
#    2060     verbose,
#    2061     with_cuda,
#    2062     with_sycl,
#    2063     is_python_module,
#    2064     is_standalone=False,
#    2065     keep_intermediates=keep_intermediates)
#
# File ~/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2134, in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    2130                 hipified_sources.add(hipify_result[s_abs].hipified_path if s_abs in hipify_result else s_abs)
#    2132             sources = list(hipified_sources)
# -> 2134         _write_ninja_file_and_build_library(
#    2135             name=name,
#    2136             sources=sources,
#    2137             extra_cflags=extra_cflags or [],
#    2138             extra_cuda_cflags=extra_cuda_cflags or [],
#    2139             extra_sycl_cflags=extra_sycl_cflags or [],
#    2140             extra_ldflags=extra_ldflags or [],
#    2141             extra_include_paths=extra_include_paths or [],
#    2142             build_directory=build_directory,
#    2143             verbose=verbose,
#    2144             with_cuda=with_cuda,
#    2145             with_sycl=with_sycl,
#    2146             is_standalone=is_standalone)
#    2147 elif verbose:
#    2148     logger.debug('No modifications detected for re-loaded extension module %s, skipping build step...', name)
#
# File ~/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2286, in _write_ninja_file_and_build_library(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_standalone)
#    2284 if verbose:
#    2285     logger.info('Building extension module %s...', name)
# -> 2286 _run_ninja_build(
#    2287     build_directory,
#    2288     verbose,
#    2289     error_prefix=f"Error building extension '{name}'")
#
# File ~/Documents/github/pytorch-cpp-ext/venv/lib/python3.12/site-packages/torch/utils/cpp_extension.py:2614, in _run_ninja_build(build_directory, verbose, error_prefix)
#    2612 if hasattr(error, 'output') and error.output:  # type: ignore[union-attr]
#    2613     message += f": {error.output.decode(*SUBPROCESS_DECODE_ARGS)}"  # type: ignore[union-attr]
# -> 2614 raise RuntimeError(message) from e
#
# RuntimeError: Error building extension 'demo_v2'

# %% [markdown]
# Two approaches - let PyTorch autogenerate pybind11 bindings (first cell), or manually write them (second cell).
